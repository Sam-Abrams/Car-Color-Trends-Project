# %% [markdown]
# ## Table of Contents
#
# 1. Importing Data and Libraries
# 2. Data Quality Checks
# 3. Data Cleaning

# %% [markdown]
# ## 1. Import Data and Libraries

# %%
## Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import skimpy
from summarytools import dfSummary

# %%
df_cars = pd.read_csv('/Users/samabrams/Data Analysis Projects/Car-Color-Trends-Project/02 Data/Original Data/used_car_prices(scraped).csv', on_bad_lines='skip')

# %%
df_cars.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca        4.5    1331.0   gray    black
# 3  yv1612tb4f1310987    ca        4.1   14282.0  white    black
# 4  wba6b2c57ed129731    ca        4.3    2641.0   gray    black
#
#                                    seller    mmr  sellingprice  \
# 0                 kia motors america, inc  20500         21500
# 1                 kia motors america, inc  20800         21500
# 2  financial services remarketing (lease)  31900         30000
# 3                 volvo na rep/world omni  27500         27750
# 4  financial services remarketing (lease)  66000         67000
#
#                                   saledate
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)

# %%
dfSummary(df_cars)
# Out:
# <style type="text/css">
# #T_cf187 thead>tr>th {
#   text-align: left;
# }
# #T_cf187_row0_col0, #T_cf187_row1_col0, #T_cf187_row2_col0, #T_cf187_row3_col0, #T_cf187_row4_col0, #T_cf187_row5_col0, #T_cf187_row6_col0, #T_cf187_row7_col0, #T_cf187_row8_col0, #T_cf187_row9_col0, #T_cf187_row10_col0, #T_cf187_row11_col0, #T_cf187_row12_col0, #T_cf187_row13_col0, #T_cf187_row14_col0, #T_cf187_row15_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_cf187_row0_col1, #T_cf187_row1_col1, #T_cf187_row2_col1, #T_cf187_row3_col1, #T_cf187_row4_col1, #T_cf187_row5_col1, #T_cf187_row6_col1, #T_cf187_row7_col1, #T_cf187_row8_col1, #T_cf187_row9_col1, #T_cf187_row10_col1, #T_cf187_row11_col1, #T_cf187_row12_col1, #T_cf187_row13_col1, #T_cf187_row14_col1, #T_cf187_row15_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_cf187_row0_col2, #T_cf187_row1_col2, #T_cf187_row2_col2, #T_cf187_row3_col2, #T_cf187_row4_col2, #T_cf187_row5_col2, #T_cf187_row6_col2, #T_cf187_row7_col2, #T_cf187_row8_col2, #T_cf187_row9_col2, #T_cf187_row10_col2, #T_cf187_row11_col2, #T_cf187_row12_col2, #T_cf187_row13_col2, #T_cf187_row14_col2, #T_cf187_row15_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_cf187_row0_col3, #T_cf187_row1_col3, #T_cf187_row2_col3, #T_cf187_row3_col3, #T_cf187_row4_col3, #T_cf187_row5_col3, #T_cf187_row6_col3, #T_cf187_row7_col3, #T_cf187_row8_col3, #T_cf187_row9_col3, #T_cf187_row10_col3, #T_cf187_row11_col3, #T_cf187_row12_col3, #T_cf187_row13_col3, #T_cf187_row14_col3, #T_cf187_row15_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_cf187_row0_col4, #T_cf187_row1_col4, #T_cf187_row2_col4, #T_cf187_row3_col4, #T_cf187_row4_col4, #T_cf187_row5_col4, #T_cf187_row6_col4, #T_cf187_row7_col4, #T_cf187_row8_col4, #T_cf187_row9_col4, #T_cf187_row10_col4, #T_cf187_row11_col4, #T_cf187_row12_col4, #T_cf187_row13_col4, #T_cf187_row14_col4, #T_cf187_row15_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_cf187_row0_col5, #T_cf187_row1_col5, #T_cf187_row2_col5, #T_cf187_row3_col5, #T_cf187_row4_col5, #T_cf187_row5_col5, #T_cf187_row6_col5, #T_cf187_row7_col5, #T_cf187_row8_col5, #T_cf187_row9_col5, #T_cf187_row10_col5, #T_cf187_row11_col5, #T_cf187_row12_col5, #T_cf187_row13_col5, #T_cf187_row14_col5, #T_cf187_row15_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_cf187">
#   <caption><strong>Data Frame Summary</strong><br>df_cars<br>Dimensions: 558,811 x 16<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_cf187_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_cf187_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_cf187_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_cf187_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_cf187_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_cf187_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cf187_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_cf187_row0_col1" class="data row0 col1" ><strong>year</strong><br>[int64]</td>
#       <td id="T_cf187_row0_col2" class="data row0 col2" >Mean (sd) : 2010.0 (4.0)<br>min < med < max:<br>1982.0 < 2012.0 < 2015.0<br>IQR (CV) : 6.0 (506.7)</td>
#       <td id="T_cf187_row0_col3" class="data row0 col3" >34 distinct values</td>
#       <td id="T_cf187_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_cf187_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_cf187_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_cf187_row1_col1" class="data row1 col1" ><strong>make</strong><br>[object]</td>
#       <td id="T_cf187_row1_col2" class="data row1 col2" >1. Ford<br>2. Chevrolet<br>3. Nissan<br>4. Toyota<br>5. Dodge<br>6. Honda<br>7. Hyundai<br>8. BMW<br>9. Kia<br>10. Chrysler<br>11. other</td>
#       <td id="T_cf187_row1_col3" class="data row1 col3" >93,554 (16.7%)<br>60,197 (10.8%)<br>53,946 (9.7%)<br>39,871 (7.1%)<br>30,710 (5.5%)<br>27,206 (4.9%)<br>21,816 (3.9%)<br>20,719 (3.7%)<br>18,077 (3.2%)<br>17,276 (3.1%)<br>175,439 (31.4%)</td>
#       <td id="T_cf187_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_cf187_row1_col5" class="data row1 col5" >10,301<br>(1.8%)</td>
#     </tr>
#     <tr>
#       <td id="T_cf187_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_cf187_row2_col1" class="data row2 col1" ><strong>model</strong><br>[object]</td>
#       <td id="T_cf187_row2_col2" class="data row2 col2" >1. Altima<br>2. F-150<br>3. Fusion<br>4. Camry<br>5. Escape<br>6. nan<br>7. Focus<br>8. Accord<br>9. 3 Series<br>10. Grand Caravan<br>11. other</td>
#       <td id="T_cf187_row2_col3" class="data row2 col3" >19,349 (3.5%)<br>14,479 (2.6%)<br>12,946 (2.3%)<br>12,545 (2.2%)<br>11,861 (2.1%)<br>10,399 (1.9%)<br>10,394 (1.9%)<br>9,127 (1.6%)<br>8,204 (1.5%)<br>7,941 (1.4%)<br>441,566 (79.0%)</td>
#       <td id="T_cf187_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_cf187_row2_col5" class="data row2 col5" >10,399<br>(1.9%)</td>
#     </tr>
#     <tr>
#       <td id="T_cf187_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_cf187_row3_col1" class="data row3 col1" ><strong>trim</strong><br>[object]</td>
#       <td id="T_cf187_row3_col2" class="data row3 col2" >1. Base<br>2. SE<br>3. LX<br>4. Limited<br>5. LT<br>6. XLT<br>7. LS<br>8. LE<br>9. GLS<br>10. S<br>11. other</td>
#       <td id="T_cf187_row3_col3" class="data row3 col3" >55,817 (10.0%)<br>43,648 (7.8%)<br>20,757 (3.7%)<br>18,356 (3.3%)<br>16,915 (3.0%)<br>16,741 (3.0%)<br>13,427 (2.4%)<br>12,903 (2.3%)<br>12,331 (2.2%)<br>11,883 (2.1%)<br>336,033 (60.1%)</td>
#       <td id="T_cf187_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_cf187_row3_col5" class="data row3 col5" >10,651<br>(1.9%)</td>
#     </tr>
#     <tr>
#       <td id="T_cf187_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_cf187_row4_col1" class="data row4 col1" ><strong>body</strong><br>[object]</td>
#       <td id="T_cf187_row4_col2" class="data row4 col2" >1. Sedan<br>2. SUV<br>3. sedan<br>4. suv<br>5. Hatchback<br>6. Minivan<br>7. Coupe<br>8. Wagon<br>9. Crew Cab<br>10. nan<br>11. other</td>
#       <td id="T_cf187_row4_col3" class="data row4 col3" >199,437 (35.7%)<br>119,292 (21.3%)<br>41,906 (7.5%)<br>24,552 (4.4%)<br>21,380 (3.8%)<br>21,363 (3.8%)<br>14,602 (2.6%)<br>13,630 (2.4%)<br>13,280 (2.4%)<br>13,195 (2.4%)<br>76,174 (13.6%)</td>
#       <td id="T_cf187_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_cf187_row4_col5" class="data row4 col5" >13,195<br>(2.4%)</td>
#     </tr>
#     <tr>
#       <td id="T_cf187_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_cf187_row5_col1" class="data row5 col1" ><strong>transmission</strong><br>[object]</td>
#       <td id="T_cf187_row5_col2" class="data row5 col2" >1. automatic<br>2. nan<br>3. manual</td>
#       <td id="T_cf187_row5_col3" class="data row5 col3" >475,914 (85.2%)<br>65,353 (11.7%)<br>17,544 (3.1%)</td>
#       <td id="T_cf187_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_cf187_row5_col5" class="data row5 col5" >65,353<br>(11.7%)</td>
#     </tr>
#     <tr>
#       <td id="T_cf187_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_cf187_row6_col1" class="data row6 col1" ><strong>vin</strong><br>[object]</td>
#       <td id="T_cf187_row6_col2" class="data row6 col2" >1. wbanv13588cz57827<br>2. 1ftfw1cv5afb30053<br>3. wp0ca2988xu629622<br>4. 5n1ar1nn2bc632869<br>

# %% [markdown]
# ## 2. Data Quality Checks

# %%
## Check for missing values

df_cars.isnull().sum().sort_values(ascending=True)
# Out:
# year                0
# vin                 0
# state               0
# seller              0
# mmr                 0
# sellingprice        0
# saledate            0
# odometer           94
# color             749
# interior          749
# make            10301
# model           10399
# trim            10651
# condition       11794
# body            13195
# transmission    65353
# dtype: int64

# %% [markdown]
# ---
# Make and model aren't key to my analysis, nor do those missing values make a huge dent in my total number of entries, so records missing those will be removed. I'm going to leave the records that are missing condition, body, or transmission, assuming they have enough relevant info in other columns.

# %%
## verify data types

df_cars.dtypes
# Out:
# year              int64
# make             object
# model            object
# trim             object
# body             object
# transmission     object
# vin              object
# state            object
# condition       float64
# odometer        float64
# color            object
# interior         object
# seller           object
# mmr               int64
# sellingprice      int64
# saledate         object
# dtype: object

# %%
## Check for duplicates

df_cars.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ---
# no duplicates, yay!

# %%
## Check for year values

pd.set_option('display.max_rows', None)
df_cars['year'].value_counts().sort_index()
# Out:
# year
# 1982         2
# 1983         1
# 1984         5
# 1985        10
# 1986        11
# 1987         8
# 1988        11
# 1989        20
# 1990        49
# 1991        67
# 1992       132
# 1993       205
# 1994       392
# 1995       711
# 1996       851
# 1997      1546
# 1998      2149
# 1999      3363
# 2000      5227
# 2001      6468
# 2002      9715
# 2003     13281
# 2004     17342
# 2005     21394
# 2006     26913
# 2007     30845
# 2008     31502
# 2009     20594
# 2010     26485
# 2011     48548
# 2012    102315
# 2013     98168
# 2014     81070
# 2015      9411
# Name: count, dtype: int64

# %%
## Check distribution of odometer readings and sell prices

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(df_cars['odometer'], bins=50, alpha=0.7, color='blue')
plt.title('Distribution of Odometer Readings')
plt.xlabel('Odometer (miles)')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.hist(df_cars['sellingprice'], bins=50, alpha=0.7, color='green')
plt.title('Distribution of Selling Prices')
plt.xlabel('Selling Price ($)')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
## Check for outliers

## percentile-based filtering
print("Data distribution analysis:")
print(df_cars[['odometer', 'sellingprice']].describe([0.01, 0.05, 0.95, 0.99]))

## Filter to 95th or 99th percentile for visualization
odometer_99th = df_cars['odometer'].quantile(0.99)
price_99th = df_cars['sellingprice'].quantile(0.99)

print(f"\n99th percentile cutoffs:")
print(f"Odometer: {odometer_99th:,.0f} miles")
print(f"Price: ${price_99th:,.0f}")
# Out:
# Data distribution analysis:
#             odometer   sellingprice
# count  558717.000000  558811.000000
# mean    68323.195797   13611.262461
# std     53397.752933    9749.656919
# min         1.000000       1.000000
# 1%       3307.160000     500.000000
# 5%      10518.000000    1500.000000
# 50%     52256.000000   12100.000000
# 95%    170059.000000   30600.000000
# 99%    226671.400000   44900.000000
# max    999999.000000  230000.000000
#
# 99th percentile cutoffs:
# Odometer: 226,671 miles
# Price: $44,900

# %%
df_cars['odometer'].value_counts().sort_index(ascending=False).head(100)
# Out:
# odometer
# 999999.0    72
# 980113.0     1
# 959276.0     1
# 694978.0     2
# 621388.0     1
# 580956.0     1
# 537334.0     1
# 522212.0     1
# 500227.0     1
# 495757.0     1
# 480747.0     1
# 471114.0     1
# 470368.0     1
# 463731.0     1
# 462759.0     1
# 462579.0     1
# 458419.0     1
# 458184.0     1
# 456004.0     1
# 453041.0     1
# 451641.0     1
# 451419.0     1
# 451362.0     1
# 450825.0     1
# 446425.0     1
# 446073.0     1
# 445317.0     1
# 443236.0     1
# 440763.0     1
# 439031.0     1
# 438637.0     1
# 438180.0     1
# 436372.0     1
# 435589.0     1
# 434901.0     1
# 433117.0     1
# 429577.0     1
# 429394.0     1
# 428472.0     1
# 427587.0     1
# 426418.0     1
# 424469.0     1
# 423691.0     1
# 419894.0     1
# 412509.0     1
# 411780.0     1
# 411053.0     1
# 410688.0     1
# 406777.0     1
# 406746.0     1
# 402934.0     1
# 398532.0     1
# 397857.0     1
# 396793.0     1
# 396211.0     1
# 395827.0     1
# 394130.0     1
# 393276.0     1
# 392674.0     1
# 392573.0     1
# 392570.0     1
# 392026.0     1
# 391918.0     1
# 391701.0     1
# 389735.0     1
# 389409.0     1
# 388607.0     1
# 387537.0     1
# 387123.0     1
# 386001.0     1
# 385140.0     1
# 382892.0     1
# 382878.0     1
# 382600.0     1
# 382592.0     1
# 382200.0     1
# 381875.0     1
# 380842.0     1
# 380347.0     1
# 379439.0     1
# 379307.0     1
# 379069.0     1
# 379013.0     1
# 378670.0     1
# 378575.0     1
# 378474.0     1
# 378315.0     1
# 378037.0     1
# 378031.0     1
# 377766.0     1
# 376620.0     1
# 376574.0     1
# 376426.0     1
# 376300.0     1
# 375455.0     1
# 375363.0     1
# 374598.0     1
# 373909.0     1
# 373703.0     1
# 372902.0     1
# Name: count, dtype: int64

# %%
## Investigating the 999,999+ mileage entries more closely

df_cars[df_cars['odometer'] == 999999.0]
# Out:
#         year           make           model           trim           body  \
# 275     2013        Hyundai   Elantra Coupe             GS  Elantra Coupe
# 4626    2003      Chevrolet  Silverado 1500             LS   Extended Cab
# 13317   2009      Chevrolet          Cobalt             LT          Coupe
# 13480   2009          Dodge         Charger           Base          Sedan
# 13568   2009          Dodge         Charger           Base          Sedan
# 20838   2006            Kia          Amanti           Base          Sedan
# 38465   2012         Nissan          Altima          2.5 S          Sedan
# 39178   2009          Dodge   Grand Caravan            SXT        Minivan
# 40121   2006           Ford           F-150     King Ranch      SuperCrew
# 55492   2005         Nissan           Quest         3.5 SE        Minivan
# 57588   2008         Nissan           Rogue              S            SUV
# 58330   2006       chrysler             300  4x2 v8 c srt8            NaN
# 59320   2004         nissan            350z            NaN            NaN
# 61824   2013            Kia          Optima             SX          Sedan
# 70798   2010      Chevrolet          Cobalt             LT          Sedan
# 76882   2008      Chevrolet          Impala             LS          Sedan
# 81661   2012        Hyundai          Sonata            GLS          Sedan
# 83882   2005           Ford          Escape            XLT            SUV
# 84086   2004      Chevrolet           Tahoe             LS            SUV
# 96234   2013      Chevrolet           Cruze             LS          Sedan
# 103031  2013           Ford          Escape             SE            SUV
# 117926  2005         Nissan           Quest         3.5 SE        Minivan
# 117972  2005          Volvo             S40           2.4i          Sedan
# 118104  2014          Dodge         Journey             SE            SUV
# 135334  2010          Mazda            CX-7        i Sport            SUV
# 136242  2007        Pontiac      Grand Prix           Base          Sedan
# 163868  2001            BMW              X5           4.4i            SUV
# 166054  2004      Chevrolet           Tahoe             LS            SUV
# 168800  2009          Dodge   Grand Caravan             SE        Minivan
# 179448  2014        Hyundai          Sonata            GLS          Sedan
# 191690  2014         Toyota           Camry             SE          Sedan
# 194973  2009         Saturn             VUE             XE            SUV
# 240950  2003           Ford      Expedition      XLT Value            SUV
# 245595  2005            Kia          Sedona             EX        Minivan
# 260722  2003            NaN             NaN            NaN            NaN
# 260729  2003            NaN             NaN            NaN            NaN
# 275351  2006          Mazda         Tribute              i            SUV
# 279980  2007      Chevrolet           Tahoe             LT            SUV
# 290236  2001           Ford        Windstar            SEL        Minivan
# 321671  1999           Ford      Expedition            XLT            SUV
# 321728  1998          Lexus          ES 300           Base          Sedan
# 323274  2003            BMW              X5           3.0i            SUV
# 338793  2011           Ford           Focus             SE          Sedan
# 347888  2006         Nissan           Quest         3.5 SE        Minivan
# 354485  2003         Nissan          Altima         3.5 SE          Sedan
# 361178  2003          Buick           Regal             LS          Sedan
# 367686  2005            BMW        6 Series          645Ci    Convertible
# 373462  2013      Chevrolet          Malibu             LT          Sedan
# 385365  2001  Mercedes-Benz         C-Class           C240          Sedan
# 385721  2014            Kia           Forte             EX          Sedan
# 398167  2003  Mercedes-Benz         C-Class           C240          Sedan
# 404788  2013            Kia          Optima             SX          Sedan
# 406428  2005        Hyundai         Elantra            GLS          Sedan
# 409935  1993           Ford           F-150             XL    Regular Cab
# 417515  2001      Chevrolet  Silverado 1500           Base    Regular Cab
# 418605  2011         Nissan          Altima          2.5 S          Sedan
# 451991  2007           Ford          Taurus      SEL Fleet          Sedan
# 452007  2007            NaN             NaN            NaN            NaN
# 452254  1999     Mitsubishi  Eclipse Spyder             GS    Convertible
# 452267  1996       Chrysler         Sebring            JXi    Convertible
# 456527  2001      Chevrolet  Silverado 1500             LS   Extended Cab
# 462004  2008           Jeep         Liberty          Sport            SUV
# 462289  2006      Chevrolet  Silverado 1500             LS   Extended Cab
# 476582  2007          Buick      Rendezvous             CX            suv
# 477244  2002           Ford           F-150             XL    regular cab
# 485257  2005  Mercedes-Benz         S-Class    S500 4MATIC          sedan
# 485594  1997          Mazda         Protege             LX          sedan
# 489822  2008       Chrysler             300        Touring          sedan
# 490450  2002           Ford      Expedition    Eddie Bauer            suv
# 501462  2011     Volkswagen           Jetta            SEL          sedan
# 513201  2006           Ford          Taurus            SEL          sedan
# 541011  2007        Pontiac      Grand Prix           Base          sedan
#
#        transmission                vin state  condition  odometer     color  \
# 275       automatic  kmhdh6ae8du017422    ca        1.0  999999.0      blue
# 4626      automatic  1gcec19v43e225059    ca        2.0  999999.0      gray
# 13317     automatic  1g1at18h797165360    tx        NaN  999999.0     white
# 13480     automatic  2b3ka43d49h578284    il        1.0  999999.0     black
# 13568     automatic  2b3ka43dx9h521300    tx        1.0  999999.0      blue
# 20838     automatic  knald124265085150    ms        1.0  999999.0      gray
# 38465     automatic  1n4al2ap3cn462083    oh        1.0  999999.0     white
# 39178     automatic  2d8hn54149r643041    md        1.0  999999.0     black
# 40121     automatic  1ftpw14556ka64749    ga        1.9  999999.0     black
# 55492     automatic  5n1bv28u15n131795    il        1.9  999999.0     green
# 409935    automatic  2ftdf15y0pcb40606    ms        1.0  999999.0      blue
# 417515    automatic  1gcec14w01z222665    fl        1.0  999999.0     white
# 418605    automatic  1n4al2ap1bn503809    ms        2.3  999999.0      blue
# 451991    automatic  1fafp56u27a127873    ms        1.9  999999.0     white
# 452007       manual  jm1fe173870213192    tx        2.3  999999.0       red
# 452254    automatic  4a3ax35g5xe138358    fl        2.0  999999.0    silver
# 452267    automatic  3c3el55h5tt314652    fl        3.0  999999.0     green
# 456527    automatic  1gcec19v81z169441    ca        1.0  999999.0     white
# 462004    automatic  1j8gp28k28w115292    tx        1.9  999999.0     green
# 462289    automatic  2gcec19v261319172    ca        2.0  999999.0       red
# 476582    automatic  3g5da03lx7s587886    oh        2.0  999999.0     white
# 477244    automatic  1ftrf17292nb99722    fl        1.9  999999.0      blue
# 485257    automatic  wdbng84j05a442389    ny        1.0  999999.0     black
# 485594    automatic  jm1bc141xv0109453    fl        1.0  999999.0      blue
# 489822    automatic  2c3la53g88h288734    ca        2.7  999999.0    silver
# 490450    automatic  1fmru17l72la49923    tx        2.0  999999.0     black
# 501462          NaN  3vwlx7aj1bm387406    tx        1.0  999999.0     white
# 513201    automatic  1fafp56u06a197709    oh        1.9  999999.0      gray
# 541011    automatic  2g2wp552771212846    ms        1.0  999999.0      blue
#
#        interior                                             seller    mmr  \
# 275        gray                              hyundai motor finance   8025
# 4626       gray                                      800 loan mart   1425
# 13317      gray                                        mei finance   3375
# 13480      gray                                 santander consumer   3850
# 13568     black                                 santander consumer   4150
# 20838     beige                     fiserv/global lending services    900
# 38465     black                                 santander consumer   7375
# 39178      gray                                 santander consumer   3325
# 40121     brown                        wells fargo dealer services   7500
# 55492      gray                                 santander consumer   2250
# 57588       NaN                        wells fargo dealer services   3650
# 58330     black                                 santander consumer   7700
# 59320     black                        wells fargo dealer services   4350
# 61824     black                              hyundai motor finance  17700
# 70798     black                                 santander consumer   2850
# 76882         —                             automotive credit corp   1850
# 81661      gray                                 santander consumer   9275
# 83882      gray                                 santander consumer    850
# 84086       tan                                 santander consumer    875
# 96234     black                                 santander consumer   7975
# 103031     gray       regional acceptance corporation / greenville  10750
# 117926    beige                                         355 toyota   1725
# 117972    black                                 santander consumer   1200
# 118104    black                                   chrysler capital  12800
# 135334    black                           caprock auto remarketing   5600
# 136242    black                                 santander consumer   1200
# 163868     gray                             lexus of silver spring   1325
# 166054     gray                                      800 loan mart   3725
# 168800     gray                                 santander consumer   1550
# 179448     gray  enterprise vehicle exchange / tra / rental / t...  12550
# 191690    black                                 santander consumer  15400
# 194973     gray                                 santander consumer   4425
# 240950     gray                                      800 loan mart    700
# 245595      tan              credit acceptance corp/vrs/southfield    100
# 260722     gray                       onemain remarketing services   1375
# 260729     gray              credit acceptance corp/vrs/southfield    625
# 275351      tan                                 santander consumer   1800
# 279980     gray                       innovate loan servicing corp   6150
# 290236      tan                              carsense incorporated     50
# 321671     gray              credit acceptance corp/vrs/southfield    175
# 476582          2250  Tue Jun 02 2015 02:30:00 GMT-0700 (PDT)
# 477244           900  Thu May 28 2015 06:00:00 GMT-0700 (PDT)
# 485257          1700  Wed Jun 03 2015 02:00:00 GMT-0700 (PDT)
# 485594           325  Thu Jun 04 2015 05:20:00 GMT-0700 (PDT)
# 489822          1200  Tue Jun 02 2015 06:00:00 GMT-0700 (PDT)
# 490450           600  Wed Jun 03 2015 03:20:00 GMT-0700 (PDT)
# 501462          1100  Wed Jun 03 2015 05:30:00 GMT-0700 (PDT)
# 513201           400  Thu Jun 11 2015 02:00:00 GMT-0700 (PDT)
# 541011           600  Thu Jun 18 2015 05:02:00 GMT-0700 (PDT)

# %% [markdown]
# ---
# It seems like the 999999.0 odometer values are used when the odometer reading is over 1 million miles, so I'm going to leave those vehicles in for the sake of the color analysis.

# %%
## Check for unusual VIN patterns

df_cars['vin'].str.len().value_counts().head()
# Out:
# vin
# 17    558811
# Name: count, dtype: int64

# %% [markdown]
# ---
# VIN numbers are all the same length, all good there.

# %%
## Quick check to see how many records are missing both make and model

## Detailed missing pattern analysis
missing_make = df_cars['make'].isna()
missing_model = df_cars['model'].isna()
both_missing = missing_make & missing_model

print(f"Missing make only: {(missing_make & ~missing_model).sum()}")
print(f"Missing model only: {(missing_model & ~missing_make).sum()}")
print(f"Missing both make AND model: {both_missing.sum()}")
print(f"Missing either make OR model: {(missing_make | missing_model).sum()}")
# Out:
# Missing make only: 0
# Missing model only: 98
# Missing both make AND model: 10301
# Missing either make OR model: 10399

# %% [markdown]
# ---
# It appears that no record are only missing the make. If they are missing the model, then they are also missing the make of the vehicle, so I will be removing that 10,399 records for the final analysis.

# %% [markdown]
# # Data Quality Assessment & Cleaning Strategy
#
# ## Fields Requiring No Action
# **Complete data with no missing values:**
# - **year** - Vehicle manufacturing year
# - **vin** - Vehicle identification number
# - **state** - Sale location
# - **seller** - Selling entity
# - **mmr** - Market value estimate
# - **sellingprice** - Final sale price
# - **saledate** - Date of sale
# - **odometer** - Mileage reading
#
# ## Critical Fields: Remove Records with Missing Data
# **These fields are essential for our color trend analysis:**
#
# - **color** → Remove 749 records (0.13% of dataset)
#  - *Rationale: Primary analysis variable - cannot analyze color trends without color data*
#
# - **interior** → Remove 749 records (0.13% of dataset)
#  - *Rationale: Secondary analysis variable for comprehensive color coordination insights*
#
# - **make** → Remove 10,301 records (1.8% of dataset)
#  - *Rationale: Essential for brand-level color strategy analysis*
#
# - **model** → Remove 10,399 records (1.9% of dataset)
#  - *Rationale: Required for vehicle segment and type classification*
#
# ## Non-Critical Fields: Retain with Missing Data Flags
# **These fields enhance analysis but are not essential:**
#
# - **trim** - Vehicle trim level
# - **condition** - Vehicle condition rating
# - **body** - Vehicle body style
# - **transmission** - Transmission type
#
# *Strategy: Create analytical flags (e.g., `has_transmission`) to enable subset analysis while retaining maximum sample size for core color insights.*
#
# ## Expected Data Retention
# - **Starting Records:** 558,811
# - **Records to Remove:** ~21,000 (3.8%)
# - **Final Clean Dataset:** ~538,000 records (96.2% retention)
